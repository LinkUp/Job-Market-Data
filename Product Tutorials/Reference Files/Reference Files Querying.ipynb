# %% [markdown]
# #  The purpose of this document is to learn how to query and navigate the reference files for information.  When you go to train a model, or develop a signal, these files will be joined with job records, dropping reference materials with no job records.

# %% [markdown]
# # Import reference files
#
# 1. PIT Ticker
# 2. PIT Company Reference
# 3. Scrape Log

# %%
import pandas as pd

# Choose a ticker to look at
Ticker = 'AMZN'
Company_name = 'Amazon'

# %%
PIT_Ticker = pd.read_csv('../raw-sample/raw_pit_ticker_full.csv.gz')
PIT_Company = pd.read_csv('../raw-sample/raw_pit_company_reference_full.csv.gz')
ScrapeLog = pd.read_csv('../raw-sample/raw_company_scrape_log_full.csv.gz')

# %% [markdown]
# # Look up Company ID and other information based on company name

# %%
PIT_Company[PIT_Company['company_name'].str.contains(Company_name, case = False)==True]
# Out:
#        company_id  start_date    end_date  \
# 411           469  2016-02-24         NaN
# 19413       19202  2016-02-24         NaN
# 34088       33625  2016-02-24         NaN
# 41695       41053  2016-11-29         NaN
# 58218       58103  2018-11-21         NaN
# 59639       59981  2019-04-30         NaN
# 59671       60064  2019-05-03  2019-05-07
# 59672       60064  2019-05-08         NaN
# 59673       60065  2019-05-03  2019-05-07
# 59674       60065  2019-05-08         NaN
# 60486       61212  2019-07-12         NaN
# 60574       61335  2019-07-19         NaN
#
#                                      company_name  \
# 411                              Amazon.com, Inc.
# 19413                               Amazon Lab126
# 34088                            Amazon.com, Inc.
# 41695                                      Amazon
# 58218  Amazon Contracted Delivery Service Partner
# 59639                      Amazon AWS - Technical
# 59671                                 Amazon Flex
# 59672                                 Amazon Flex
# 59673                                  Amazon HVH
# 59674                                  Amazon HVH
# 60486                               Amazon - BOS7
# 60574                                      Amazon
#
#                           company_url                   lei open_perm_id  \
# 411             http://www.amazon.com  ZXTILKJKG63JELOEG630   4295905494
# 19413           http://www.lab126.com  ZXTILKJKG63JELOEG630   4295905494
# 34088               http://amazon.com  ZXTILKJKG63JELOEG630   4295905494
# 41695  http://www.amazondelivers.jobs                   NaN   4296241666
# 58218     http://logistics.amazon.com                   NaN          NaN
# 59639           http://aws.amazon.com                   NaN          NaN
# 59671          http://flex.amazon.com                   NaN          NaN
# 59672          http://flex.amazon.com                   NaN   4295905494
# 59673         http://amazon.force.com                   NaN          NaN
# 59674         http://amazon.force.com                   NaN          NaN
# 60486           http://www.amazon.com                   NaN          NaN
# 60574           http://www.amazon.com                   NaN          NaN
#
#        naics_code
# 411      454110.0
# 19413    541715.0
# 34088    454113.0
# 41695    454110.0
# 58218         NaN
# 59639         NaN
# 59671         NaN
# 59672    454110.0
# 59673         NaN
# 59674    454110.0
# 60486         NaN
# 60574         NaN

# %% [markdown]
# # Look up Company Ids based on Ticker

# %%
Company_IDs = PIT_Ticker[PIT_Ticker['company_id'].isin(
    PIT_Ticker[PIT_Ticker['stock_ticker']==Ticker]['company_id'].unique())]['company_id'].unique()
Company_IDs
# Out:
# array([  227,   469,   945,  2868, 21652, 25784, 33164, 33625, 35288,
#        35368, 41053, 42767])

# %% [markdown]
# # Look for all scrape changes based Company IDs

# %%
ScrapeLog[(ScrapeLog['company_id'].isin(Company_IDs)) & (ScrapeLog['scrape_changed']==True)].head(10)
# Out:
#         company_id        date  scrape_run_complete  scrape_changed
# 158254         227  2012-05-07                 True            True
# 158258         227  2012-05-14                 True            True
# 158266         227  2012-05-29                 True            True
# 158361         227  2013-01-14                 True            True
# 158560         227  2014-08-13                 True            True
# 158742         227  2019-04-17                 True            True
# 158792         227  2019-07-29                 True            True
# 295589         469  2010-05-17                False            True
# 295590         469  2010-05-18                False            True
# 295737         469  2011-08-02                False            True

# %% [markdown]
# # Look up company reference file with Company IDs

# %%
PIT_Company[PIT_Company['company_id'].isin(Company_IDs)]
# Out:
#        company_id  start_date    end_date        company_name  \
# 217           227  2016-02-24         NaN          ACME Tools
# 411           469  2016-02-24         NaN    Amazon.com, Inc.
# 906           945  2017-06-02         NaN    Zappos.com, Inc.
# 2923         2868  2016-02-24         NaN  Whole Foods Market
# 21667       21652  2016-02-24  2016-06-28           Justin.TV
# 21668       21652  2016-06-28  2017-02-12              Twitch
# 21669       21652  2017-02-13         NaN              Twitch
# 25958       25784  2016-02-24         NaN        Kiva Systems
# 33622       33164  2016-02-24         NaN            Souq.com
# 34088       33625  2016-02-24         NaN    Amazon.com, Inc.
# 35841       35288  2016-02-24         NaN  Whole Foods Market
# 35932       35368  2016-02-24         NaN          comiXology
# 41695       41053  2016-11-29         NaN              Amazon
# 43448       42767  2017-06-02         NaN  Whole Foods Market
#
#                            company_url                   lei open_perm_id  \
# 217            http://www.acmetool.com                   NaN          NaN
# 411              http://www.amazon.com  ZXTILKJKG63JELOEG630   4295905494
# 906              http://www.zappos.com                   NaN   4296946300
# 2923         http://www.wholefoods.com                   NaN   4295908472
# 21667             http://www.justin.tv                   NaN   5042932082
# 21668             http://www.justin.tv                   NaN   5042932082
# 21669             http://www.twitch.tv                   NaN   5042932082
# 25958       http://www.kivasystems.com                   NaN   4297527928
# 33622              http://www.souq.com                   NaN   5050292230
# 34088                http://amazon.com  ZXTILKJKG63JELOEG630   4295905494
# 35841  http://www.wholefoodsmarket.com                   NaN   4295908472
# 35932        http://www.comixology.com                   NaN          NaN
# 41695   http://www.amazondelivers.jobs                   NaN   4296241666
# 43448  http://www.wholefoodsmarket.com                   NaN          NaN
#
#        naics_code
# 217           NaN
# 411      454110.0
# 906      448210.0
# 2923          NaN
# 21667    517311.0
# 21668    517311.0
# 21669    517311.0
# 25958         NaN
# 33622    448120.0
# 34088    454113.0
# 35841         NaN
# 35932         NaN
# 41695    454110.0
# 43448         NaN

# %% [markdown]
# # Look up all history for companies that have ever had a specified ticker

# %%
PIT_Ticker[PIT_Ticker['company_id'].isin(PIT_Ticker[PIT_Ticker['stock_ticker']==Ticker]['company_id'].unique())]
# Out:
#        company_id  start_date    end_date stock_ticker stock_exchange_country  \
# 442           227  1999-11-09         NaN         AMZN                     CL
# 443           227  1999-11-09         NaN         AMZN                     IT
# 444           227  1999-11-09         NaN          AMZ                     DE
# 445           227  1999-11-09         NaN         0R1O                     GB
# 446           227  1999-11-09         NaN         AMZN                     CH
# 447           227  1999-11-09         NaN         AMZN                     CO
# 448           227  1999-11-09         NaN         AMZN                     MX
# 449           227  1999-11-09         NaN         AMZN                     PE
# 450           227  1999-11-09         NaN         AMZN                     US
# 451           227  1999-11-09         NaN         AMZN                     AT
# 1031          469         NaN         NaN         AMZN                     CL
# 1032          469         NaN         NaN         AMZN                     IT
# 1033          469         NaN         NaN          AMZ                     DE
# 1034          469         NaN         NaN         0R1O                     GB
# 1035          469         NaN         NaN         AMZN                     CH
# 1036          469         NaN         NaN         AMZN                     CO
# 1037          469         NaN         NaN         AMZN                     MX
# 1038          469         NaN         NaN         AMZN                     PE
# 1039          469         NaN         NaN         AMZN                     AT
# 1040          469  1997-05-15         NaN         AMZN                     US
# 2017          945  2009-07-22         NaN         AMZN                     CL
# 2018          945  2009-07-22         NaN         AMZN                     IT
# 2019          945  2009-07-22         NaN          AMZ                     DE
# 2020          945  2009-07-22         NaN         0R1O                     GB
# 2021          945  2009-07-22         NaN         AMZN                     CH
# 2022          945  2009-07-22         NaN         AMZN                     CO
# 2023          945  2009-07-22         NaN         AMZN                     MX
# 2024          945  2009-07-22         NaN         AMZN                     PE
# 2025          945  2009-07-22         NaN         AMZN                     US
# 2026          945  2009-07-22         NaN         AMZN                     AT
# ...           ...         ...         ...          ...                    ...
# 39705       35368  2018-04-27         NaN         AMZN                     MX
# 39706       35368  2018-04-27         NaN         AMZN                     PE
# 39707       35368  2018-04-27         NaN         AMZN                     US
# 39708       35368  2018-04-27         NaN         AMZN                     AT
# 45048       41053         NaN         NaN         AMZN                     CL
# 45049       41053         NaN         NaN         AMZN                     IT
# 45050       41053         NaN         NaN          AMZ                     DE
# 45051       41053         NaN         NaN         0R1O                     GB
# 45052       41053         NaN         NaN         AMZN                     CH
# 45053       41053         NaN         NaN         AMZN                     CO
# 45054       41053         NaN         NaN         AMZN                     MX
# 45055       41053         NaN         NaN         AMZN                     PE
# 45056       41053         NaN         NaN         AMZN                     AT
# 45057       41053  1997-05-15         NaN         AMZN                     US
# 46869       42767         NaN  2017-08-29          WFM                     MX
# 46870       42767         NaN  2017-08-29          WFM                     DE
# 46871       42767         NaN  2017-08-29         0R04                     GB
# 46872       42767         NaN  2017-08-29          WFM                     CH
# 46873       42767  1992-01-23  2011-05-06         WFMI                     US
# 46874       42767  2011-05-06  2017-08-28          WFM                     US
# 46875       42767  2017-08-29         NaN         AMZN                     CL
# 46876       42767  2017-08-29         NaN         AMZN                     IT
# 46877       42767  2017-08-29         NaN          AMZ                     DE
# 46878       42767  2017-08-29         NaN         0R1O                     GB
# 46879       42767  2017-08-29         NaN         AMZN                     CH
# 46880       42767  2017-08-29         NaN         AMZN                     CO
# 46881       42767  2017-08-29         NaN         AMZN                     MX
# 46882       42767  2017-08-29         NaN         AMZN                     PE
# 46883       42767  2017-08-29         NaN         AMZN                     US
# 46884       42767  2017-08-29         NaN         AMZN                     AT
#
#       stock_exchange_name  primary_flag
# 442                   SGO         False
# 443                   MIL         False
# 444                   ETR         False
# 445                   LON         False
# 446                   SWX         False
# 447                   BOG         False
# 448                   MEX         False
# 449                   LIM         False
# 450                   NAS          True
# 451                   WBO         False
# 1031                  SGO         False
# 1032                  MIL         False
# 1033                  ETR         False
# 1034                  LON         False
# 1035                  SWX         False
# 1036                  BOG         False
# 1037                  MEX         False
# 1038                  LIM         False
# 1039                  WBO         False
# 1040                  NAS          True
# 2017                  SGO         False
# 2018                  MIL         False
# 2019                  ETR         False
# 2020                  LON         False
# 2021                  SWX         False
# 2022                  BOG         False
# 2023                  MEX         False
# 2024                  LIM         False
# 2025                  NAS          True
# 2026                  WBO         False
# ...                   ...           ...
# 39705                 MEX         False
# 39706                 LIM         False
# 39707                 NAS          True
# 39708                 WBO         False
# 45048                 SGO         False
# 45049                 MIL         False
# 45050                 ETR         False
# 45051                 LON         False
# 45052                 SWX         False
# 45053                 BOG         False
# 45054                 MEX         False
# 45055                 LIM         False
# 45056                 WBO         False
# 45057                 NAS          True
# 46869                 MEX         False
# 46870                 FRA         False
# 46871                 LON         False
# 46872                 SWX         False
# 46873                 NAS          True
# 46874                 NAS          True
# 46875                 SGO         False
# 46876                 MIL         False
# 46877                 ETR         False
# 46878                 LON         False
# 46879                 SWX         False
# 46880                 BOG         False
# 46881                 MEX         False
# 46882                 LIM         False
# 46883                 NAS          True
# 46884                 WBO         False
#
# [140 rows x 7 columns]

# %% [markdown]
# # Look up Ticker history based on Company ID

# %%
company_id = 469

# %%
PIT_Ticker[PIT_Ticker['company_id'] == company_id]
# Out:
#       company_id  start_date end_date stock_ticker stock_exchange_country  \
# 1031         469         NaN      NaN         AMZN                     CL
# 1032         469         NaN      NaN         AMZN                     IT
# 1033         469         NaN      NaN          AMZ                     DE
# 1034         469         NaN      NaN         0R1O                     GB
# 1035         469         NaN      NaN         AMZN                     CH
# 1036         469         NaN      NaN         AMZN                     CO
# 1037         469         NaN      NaN         AMZN                     MX
# 1038         469         NaN      NaN         AMZN                     PE
# 1039         469         NaN      NaN         AMZN                     AT
# 1040         469  1997-05-15      NaN         AMZN                     US
#
#      stock_exchange_name  primary_flag
# 1031                 SGO         False
# 1032                 MIL         False
# 1033                 ETR         False
# 1034                 LON         False
# 1035                 SWX         False
# 1036                 BOG         False
# 1037                 MEX         False
# 1038                 LIM         False
# 1039                 WBO         False
# 1040                 NAS          True
